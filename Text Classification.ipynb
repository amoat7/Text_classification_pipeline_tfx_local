# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: 1_movies_per_genre/
#   inflating: 1_movies_per_genre/Action.csv
#   inflating: 1_movies_per_genre/Adventure.csv
#   inflating: 1_movies_per_genre/Animation.csv
#   inflating: 1_movies_per_genre/Biography.csv
#   inflating: 1_movies_per_genre/Comedy.csv
#   inflating: 1_movies_per_genre/Crime.csv
#   inflating: 1_movies_per_genre/Drama.csv
#   inflating: 1_movies_per_genre/Fantasy.csv
#   inflating: 1_movies_per_genre/History.csv
#   inflating: 1_movies_per_genre/Horror.csv
#   inflating: 1_movies_per_genre/Music.csv
#   inflating: 1_movies_per_genre/Mystery.csv
#   inflating: 1_movies_per_genre/Romance.csv
#   inflating: 1_movies_per_genre/Sci-Fi.csv
#   inflating: 1_movies_per_genre/Sport.csv
#   inflating: 1_movies_per_genre/Thriller.csv
#   inflating: 1_movies_per_genre/War.csv
#    creating: 2_reviews_per_movie_raw/
#   inflating: 2_reviews_per_movie_raw/10 Cloverfield Lane 2016.csv
# ...

# %%
import pandas as pd  
df = pd.read_csv('2_reviews_per_movie_raw/10 Cloverfield Lane 2016.csv')
df.head()
# Out:
#         username  ...                                             review
# 0  Imme-van-Gorp  ...  This movie is full of suspense. It makes you g...
# 1  sonofocelot-1  ...  I'll leave this review fairly concise. <br/><b...
# 2        mhodaee  ...  I give the 5/10 out of the credit I owe to the...
# 3      fil-nik09  ...  First of all, I must say that I was expecting ...
# 4      DVR_Brale  ...  I've always loved movies with strong atmospher...
#
# [5 rows x 7 columns]

# %% [markdown]
# # Pipeline
# ## ExampleGen

# %%
from tfx.components import CsvExampleGen
from tfx.proto import example_gen_pb2
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
 
context = InteractiveContext( pipeline_root='pipeline')
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at pipeline/metadata.sqlite.

# %%
import tensorflow as tf 
import os 
import pprint
pp = pprint.PrettyPrinter()

# %%
output = example_gen_pb2.Output(
    split_config = example_gen_pb2.SplitConfig(splits=[
        example_gen_pb2.SplitConfig.Split(name="train", hash_buckets=8),
        example_gen_pb2.SplitConfig.Split(name='eval', hash_buckets=2)
    ])
)

example_gen = CsvExampleGen(input_base='2_reviews_per_movie_raw', output_config=output)
context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 14
#         uri: "pipeline/CsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
# ...

# %%
train_uri = os.path.join(example_gen.outputs['examples'].get()[0].uri, 'Split-train')

tfrecord_filenames = [os.path.join(train_uri, name) for name in os.listdir(train_uri)]

dataset = tf.data.TFRecordDataset(tfrecord_filenames, compression_type='GZIP')

for tfrecord in dataset.take(2):
    serialized_example = tfrecord.numpy()
    example = tf.train.Example()
    example.ParseFromString(serialized_example)
    pp.pprint(example)
# Out:
# features {
#   feature {
#     key: "\"date\""
#     value {
#       bytes_list {
#         value: "30 January 2019"
#       }
#     }
#   }
#   feature {
#     key: "\"helpful\""
#     value {
#       int64_list {
#         value: 102
#       }
#     }
#   }
#   feature {
#     key: "\"rating\""
#     value {
#       bytes_list {
#         value: "7"
#       }
#     }
#   }
#   feature {
#     key: "\"review\""
#     value {
#       bytes_list {
# ...

# %%
# Out:
# 'pipeline/CsvExampleGen/examples/1'
